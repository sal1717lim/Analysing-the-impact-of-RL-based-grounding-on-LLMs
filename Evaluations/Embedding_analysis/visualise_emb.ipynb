# %%
# !pip install -r /home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/requirements.txt
# Out:
# ...
#   Using cached torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
# ...
#   Using cached triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.0
#     Uninstalling torch-2.2.0:
#       Successfully uninstalled torch-2.2.0
# ^C
# ERROR: Operation cancelled by user

# %%
# !pip install blosc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install -e /home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text/babyai
# Out:
# Obtaining file:///home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text/babyai
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for babyai
# ...

# %%
# !pip install -e /home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text/gym-minigrid
# Out:
# Obtaining file:///home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text/gym-minigrid
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for gym-minigrid
# ...

# %%
# !pip install -e /home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text
# Out:
# Obtaining file:///home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/babyai-text
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for babyai-text
# ...

# %%
# !pip install -e /home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/lamorel/lamorel
# Out:
# Obtaining file:///home/aissi/Large-Scale_Grounding_LLMs_with_Online_RL-main/lamorel/lamorel
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 3.6 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 78.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 102.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 9.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 27.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 51.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 20.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 13.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !nvidia-smi
# Out:
# /bin/bash: ligne 1: nvidia-smi : commande introuvable
